# %% [markdown]
# textbook from [course](https://www.datacamp.com/courses/fundamentals-of-ai)

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# ## Classification

# %%
# Decisiopn trees
from sklearn.tree import DecisionTreeClassifier

# Logistic regression
from sklearn.linear_model import LogisticRegression

# Support Vector Machine
from sklearn.svm import SVC

# Rondom Forest
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Metrics

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true, y_predicted)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Accuracy, Precision, Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %% [markdown]
# ## Regression

# %%
# Least Squares Regression
from sklearn.linear_model import LinearRegression

# Lasso Regression
from sklearn.linear_model import Lasso

# Ridge Regression
from sklearn.linear_model import Ridge

# %%
# Non-Linear LinearRegression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x2_train = poly.fit_transform(x_train)
linear_model.fit(X=x2_train, y=y_train)

# %% [markdown]
# Metrics

# %%
# Mean Absolute Error
from sklearn.metrics import mean_absolute_error

# Median Absolute Error
from sklearn.metrics import median_absolute_error

# R^2
from sklearn.metrics import r2_score

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Dimensionality reduction

# %%
# Principal Component Analysis (sensitive to outliers)
from sklearn.decomposition import PCA

# Latent Dirichlet Allocation
from sklearn.decomposition import LatentDirichletAllocation

# Isomap
from sklearn.manifold import Isomap

# t-distributed Stochastic Neighbor Embedding
from sklearn.manifold import TSNE

# %% [markdown]
# ## Clustering

# %%
# KMeans
from sklearn.cluster import KMeans

# Spectral clustering
from sklearn.cluster import SpectralClustering

# DBSCAN (auto)
from sklearn.cluster import DBSCAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Metrics
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Anomaly Detection

# %%
# Robust Covariance (assumes normal distribution)
from sklearn.covariance import EllipticEnvelope

# One-Class SVM (Sensitive to outliers)
from sklearn.svm import OneClassSVM

# Isolation Forest
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Metrics

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Deep Learning

# %% [markdown]
# Layers
# ![image.png](attachment:image.png)

# %%
# Example 1
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential()

# Add the hidden and the output layer, specify the number of units and input/output dimensions
model.add(Dense(units=8, input_dim=16, activation='relu')) # 8 inputs
model.add(Dense(units=4, activation='softmax'))            # 4 categories outputs

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5d352f12ca36> in <module>
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#       3
#       4
#       5 model = Sequential()
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Example 2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Dense, Conv2D, MaxPooling2D, Flatten)


model = Sequential()

# Add the hidden and the output layer, specify the number of units and input/output dimensions
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
